-- %% [markdown]
-- # [alumnosa]

-- %%
USE [AlumnosDB]
GO

-- %%
/****** Object:  User [alumnosa]    Script Date: 13/6/2026 18:49:08 ******/
CREATE USER [alumnosa] FOR LOGIN [alumnosa] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %%
ALTER ROLE [db_owner] ADD MEMBER [alumnosa]
GO
ALTER ROLE [db_datareader] ADD MEMBER [alumnosa]
GO
ALTER ROLE [db_datawriter] ADD MEMBER [alumnosa]
GO

-- %% [markdown]
-- # [dbo].[Alumnos]

-- %%
/****** Object:  Table [dbo].[Alumnos]    Script Date: 13/6/2026 18:49:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Alumnos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Nombres] [nvarchar](50) NOT NULL,
	[Apellidos] [nvarchar](50) NOT NULL,
	[Edad] [int] NOT NULL,
	[Sexo] [char](1) NOT NULL,
	[FechaRegistro] [datetime] NOT NULL,
 CONSTRAINT [PK_Alumnos] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
